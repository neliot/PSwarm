# %% [markdown]
# <H1>Basic Model1 Analysis</H1>
# It is important that an experiment has been ran with <code>LoggingP=true</code> and <code>LoggingN=true</code> in the <code>Model1.properties</code> file before running this notebook.
# <br>You also need to set <code>Model=1</code> in <code>application.properties</code>

# %%
import pandas as pd
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
#SMALL_SIZE = 8
#MEDIUM_SIZE = 10
#BIGGER_SIZE = 36
#Font sizes modifiers for inclusion in papers. 
#plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
#plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
#plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
#plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
#plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 120)
# %matplotlib inline

# %%
# load all particle data from simulator
S = pd.read_csv('csv/P-1-p.csv')
coh = pd.read_csv('csv/P-1-nc.csv')
rep = pd.read_csv('csv/P-1-nr.csv')

# %% [markdown]
# <h1>LOADED DATA</h1>

# %% [markdown]
# <code>IMAG</code> is equivalent to $v(b) = v_c(b) + v_r(b)$ <br>
# <code>CMAG</code> is equivalent to $v_c(b) = \frac{1}{\lvert n_c(b)\rvert} \sum_{b' \in n_c(b)}\mathsf{ekc}(b, b')\, \vec{b b'}$ <br>
# <code>RMAG</code> is equivalent to $v_r(b) = \frac{1}{\lvert n_r(b)\rvert}\sum_{b' \in n_r(b)} k_r\left(\lVert\vec{b b'}\rVert - \mathsf{erf}(b,b') \, \right)\widehat{bb'}$

# %%
#AGGREGATED SWARM DATA 
S
# Out:
#       STEP  ID         X         Y    Z  RANGE  REPULSE  SIZE  MASS  PERIM        CX        CY   CZ      CMAG  \
# 0        0   0  0.480001 -0.140001  0.0    3.0      2.0  10.0   1.0  False -0.036667 -0.036167  0.0  0.051502
# 1        0   1  0.020000 -0.540001  0.0    3.0      2.0  10.0   1.0  False  0.036167  0.027167  0.0  0.045233
# 2        0   2  0.440001  1.320000  0.0    3.0      2.0  10.0   1.0   True -0.024429 -0.204214  0.0  0.205670
# 3        0   3 -0.400000 -1.300001  0.0    3.0      2.0  10.0   1.0  False  0.094941  0.133059  0.0  0.163458
# 4        0   4  1.160000  1.320000  0.0    3.0      2.0  10.0   1.0   True -0.132923 -0.189692  0.0  0.231628
# ...    ...  ..       ...       ...  ...    ...      ...   ...   ...    ...       ...       ...  ...       ...
# 7842   412  14 -0.061928  1.594507  0.0    3.0      2.0  10.0   1.0  False  0.003427 -0.080506  0.0  0.080578
# ...

# %% [markdown]
# <code>MAG</code> is equivalent to $v_c(b,b') = \mathsf{ekc}(b, b')\, \vec{b b'}$ <br>
# <code>DIST</code> is equivalent to $\widehat{bb'}$ <br><br>
# $\mathsf{ekc}(b, b') = \mathsf{if} \; \mathsf{per}(b) \; \mathsf{and} \; \mathsf{per}(b') \; \mathsf{then} \; \mathrm{p}_ck_c \; \mathsf{else} \; k_c$

# %%
#INTER-AGENT COHESION DATA
coh
# Out:
#       STEP  PID  NID         X         Y    Z  RANGE  REPULSE  SIZE  MASS  PERIM      COHX      COHY  COHZ       MAG  \
# 0        0    0    8 -0.879999 -0.540001  0.0    3.0      2.0  10.0   1.0   True -0.204000 -0.060000   0.0  0.212641
# 1        0    1   15 -1.080000 -1.540001  0.0    3.0      2.0  10.0   1.0   True -0.165000 -0.150000   0.0  0.222991
# 2        0    2    9 -0.299999  1.179998  0.0    3.0      2.0  10.0   1.0   True -0.111000 -0.021000   0.0  0.112969
# 3        0    3   15 -1.080000 -1.540001  0.0    3.0      2.0  10.0   1.0   True -0.102000 -0.036000   0.0  0.108167
# 4        0    4    9 -0.299999  1.179998  0.0    3.0      2.0  10.0   1.0   True -0.219000 -0.021000   0.0  0.220004
# ...    ...  ...  ...       ...       ...  ...    ...      ...   ...   ...    ...       ...       ...   ...       ...
# 7842   412   14   13 -1.429675  0.582939  0.0    3.0      2.0  10.0   1.0  False -0.205162 -0.151735   0.0  0.255176
# ...

# %% [markdown]
# <code>MAG</code> is equivalent to $v_r(b,b') = k_r\left(\lVert\vec{b b'}\rVert - \mathsf{erf}(b,b') \, \right)\widehat{bb'}$<br>
# <code>DIST</code> is equivalent to $\widehat{bb'}$ <br><br>
# $\mathsf{erf}(b, b') = \mathsf{if} \;
# \mathsf{per}(b) \; \mathsf{and} \; \mathsf{per}(b') \; \mathsf{then} \;
# p_rR_b \; \mathsf{else} \; R_b$

# %%
#INTER-AGENT REPULSION DATA
rep
# Out:
#       STEP  PID  NID         X         Y    Z  RANGE  REPULSE  SIZE  MASS  PERIM       REPX       REPY  REPZ  \
# 0        0    0    8 -0.879999 -0.540001  0.0    3.0      2.0  10.0   1.0   True  27.936531   8.216616   0.0
# 1        0    1   15 -1.080000 -1.540001  0.0    3.0      2.0  10.0   1.0   True  18.993998  17.267265   0.0
# 2        0    2    9 -0.299999  1.179998  0.0    3.0      2.0  10.0   1.0   True  61.257000  11.589273   0.0
# 3        0    3   15 -1.080000 -1.540001  0.0    3.0      2.0  10.0   1.0   True  60.299034  21.281982   0.0
# 4        0    4    9 -0.299999  1.179998  0.0    3.0      2.0  10.0   1.0   True  26.543438   2.545286   0.0
# ...    ...  ...  ...       ...       ...  ...    ...      ...   ...   ...    ...        ...        ...   ...
# 7842   412   14   13 -1.429675  0.582939  0.0    3.0      2.0  10.0   1.0  False  12.012712   8.884438   0.0
# ...

# %%
# generate a DataFrame with perimeter count per step
group = S[["STEP","PERIM"]].query("PERIM == True").groupby('STEP').count().reset_index()

# %% [markdown]
# <h1>PERIMETER</h1>

# %%
plt.plot(group.STEP,group.PERIM)
plt.title("Perimeter Agents")
plt.xlabel("Time Step")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h1>AGGREGATED MAGNITUDE DATA</h1>

# %%
group1 = S[["STEP","IMAG"]].groupby('STEP').mean(0).reset_index()
group2 = S[["STEP","IMAG"]].groupby('STEP').std(0).reset_index()
group3 = S[["STEP","IMAG"]].groupby('STEP').max(0).reset_index()
group4 = S[["STEP","IMAG"]].groupby('STEP').min(0).reset_index()

# %%
a = plt.plot(group3.STEP,group3.IMAG,label='max')
b = plt.plot(group1.STEP,group1.IMAG,label='mean')
c = plt.plot(group2.STEP,group2.IMAG,label='std')
d = plt.plot(group4.STEP,group4.IMAG,label='min')
plt.title("Inter-agent Aggregated Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %%
plt.errorbar(group1.STEP,group1.IMAG,group2.IMAG,label='Cohesion magnitude',ecolor='red',color='black')
plt.title("Inter-agent Aggregated Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# <h1>COHESION</h1>

# %%
c1 = coh[["STEP","MAG"]].groupby('STEP').mean(0).reset_index()
c2 = coh[["STEP","MAG"]].groupby('STEP').std(0).reset_index()
c3 = coh[["STEP","MAG"]].groupby('STEP').max(0).reset_index()
c4 = coh[["STEP","MAG"]].groupby('STEP').min(0).reset_index()

# %%
a = plt.plot(c3.STEP,c3.MAG,label='max')
b = plt.plot(c1.STEP,c1.MAG,label='mean')
c = plt.plot(c2.STEP,c2.MAG,label='std')
d = plt.plot(c4.STEP,c4.MAG,label='min')
plt.title("Inter-agent Cohesion Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %%
plt.errorbar(c1.STEP,c1.MAG,c2.MAG,label='Cohesion magnitude',ecolor='red',color='black')
plt.title("Inter-agent Cohesion Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# <h1>REPULSION</h1>

# %%
r1 = rep[["STEP","MAG"]].groupby('STEP').mean(0).reset_index()
r2 = rep[["STEP","MAG"]].groupby('STEP').std(0).reset_index()
r3 = rep[["STEP","MAG"]].groupby('STEP').max(0).reset_index()
r4 = rep[["STEP","MAG"]].groupby('STEP').min(0).reset_index()

# %%
a = plt.plot(r3.STEP,r3.MAG,label='max')
b = plt.plot(r1.STEP,r1.MAG,label='mean')
c = plt.plot(r2.STEP,r2.MAG,label='std')
d = plt.plot(r4.STEP,r4.MAG,label='min')
plt.title("Inter-agent Repulsion Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %%
plt.errorbar(r1.STEP,r1.MAG,r2.MAG,label='Repulsion magnitude',ecolor='red',color='black')
plt.title("Inter-agent Repulsion Magnitude")
plt.legend()
plt.xlabel("Time Step")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# <h1>DISTANCE</h1>

# %%
dist = coh[["STEP","DIST"]].groupby('STEP').mean(0).reset_index()
dev = coh[["STEP","DIST"]].groupby('STEP').std(0).reset_index()

# %%
d1 = rep[["STEP","DIST"]].groupby('STEP').mean(0).reset_index()
d2 = rep[["STEP","DIST"]].groupby('STEP').std(0).reset_index()
d3 = rep[["STEP","DIST"]].groupby('STEP').max(0).reset_index()
d4 = rep[["STEP","DIST"]].groupby('STEP').min(0).reset_index()
a = plt.plot(d3.STEP,d3.DIST,label='max')
b = plt.plot(d1.STEP,d1.DIST,label='mean')
c = plt.plot(d2.STEP,d2.DIST,label='std')
d = plt.plot(d4.STEP,d4.DIST,label='min')
plt.title("Inter-agent Distance")
plt.xlabel("Time Step")
plt.legend()
plt.ylabel("Distance")
plt.show()

# %%
plt.errorbar(d1.STEP,d1.DIST,d2.DIST,label='Distance',ecolor='red',color='black')
plt.legend()
plt.title("Inter-agent Distance")
plt.xlabel("Time Step")
plt.ylabel("Distance")
plt.show()
